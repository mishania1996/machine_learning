# %%
import numpy as np
import pandas as pd

# %%
pip install catboost
# Out:
# Installing collected packages: catboost
# Successfully installed catboost-1.2.5

# %%
from sklearn.model_selection import StratifiedKFold     #k-fold cross-validation
from sklearn.feature_extraction.text import TfidfVectorizer #feature extraction module; converts raw documents (text) into a matrix of TF-IDF features
from sklearn.decomposition import TruncatedSVD              #decomposition module; used for dimensionality reduction of sparse data
from catboost import CatBoostClassifier, Pool               #gradient boosting library by Yandex that handles categorical features naturally. Pool is used to hold data and can be passed as an argument for training a CatBoost model
from catboost.utils import eval_metric                  #evaluation metrics for CatBoost models, such as accuracy, AUC (Area Under the Curve)
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings("ignore")

# %%
RAND_VAL=32
num_folds=20 ## Number of folds
n_est=500 ## Number of estimators

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
for feat in df_train.columns:
  df_train[feat] = df_train[feat].fillna('')
for feat in df_test.columns:
  df_test[feat] = df_test[feat].fillna('')
feat_cols=df_train.columns.drop(['target'])
X=df_train[feat_cols]
y=df_train['target']
cat_features = np.where(X.dtypes != np.float64)[0]
print(cat_features) #everything is categorical
# Out:
# [0 1 2 3]

# %%
folds = StratifiedKFold(n_splits=num_folds, random_state=RAND_VAL, shuffle=True)

#best_f1_scores = []
optimal_thresholds = []

for n_fold, (train_idx, valid_idx) in enumerate(folds.split(X, y)):
    X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
    X_val, y_val = X.iloc[valid_idx], y.iloc[valid_idx]

    train_pool = Pool(X_train, y_train, cat_features=cat_features)
    val_pool = Pool(X_val, y_val, cat_features=cat_features)

    clf = CatBoostClassifier(
        eval_metric='BalancedAccuracy',  # or 'Logloss', 'Accuracy'
        custom_metric='AUC',
        #task_type='GPU',
        learning_rate=0.02,
        iterations=n_est
    )

    clf.fit(train_pool, eval_set=val_pool, verbose=300)

    # Predict probabilities
    y_pred_val_prob = clf.predict_proba(X_val)[:, 1]

    # Optimize the threshold for the best F1 score
    #thresholds = np.linspace(0, 1, 101)
    #f1_scores = [f1_score(y_val, y_pred_val_prob > thresh) for thresh in thresholds]
    #best_thresh = thresholds[np.argmax(f1_scores)]
    #best_f1 = max(f1_scores)
    #best_f1_scores.append(best_f1)
    #optimal_thresholds.append(best_thresh)

    #print(f"Best F1 Score for fold {n_fold}: {best_f1} at threshold {best_thresh}")

    print("----------------")
# Out:
# 0:	learn: 0.6994607	test: 0.7408958	best: 0.7408958 (0)	total: 10.7ms	remaining: 5.36s
# 300:	learn: 0.7027665	test: 0.7454339	best: 0.7507868 (118)	total: 3.21s	remaining: 2.12s
# 499:	learn: 0.7057029	test: 0.7492273	best: 0.7507868 (118)	total: 4.9s	remaining: 0us
#
# bestTest = 0.7507867821
# bestIteration = 118
#
# Shrink model to first 119 iterations.
# ----------------
# 0:	learn: 0.6979742	test: 0.7630522	best: 0.7630522 (0)	total: 10.8ms	remaining: 5.37s
# 300:	learn: 0.7027536	test: 0.7805300	best: 0.7805300 (112)	total: 2.58s	remaining: 1.71s
# 499:	learn: 0.7056482	test: 0.7782258	best: 0.7805300 (112)	total: 5.03s	remaining: 0us
#
# bestTest = 0.7805299539
# bestIteration = 112
#
# Shrink model to first 113 iterations.
# ----------------
# 0:	learn: 0.7020102	test: 0.6860880	best: 0.6860880 (0)	total: 18.8ms	remaining: 9.39s
# 300:	learn: 0.7082798	test: 0.6783607	best: 0.6981426 (1)	total: 3.16s	remaining: 2.09s
# 499:	learn: 0.7109737	test: 0.6852029	best: 0.6981426 (1)	total: 4.81s	remaining: 0us
#
# bestTest = 0.6981426323
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# ----------------
# 0:	learn: 0.6999749	test: 0.6981426	best: 0.6981426 (0)	total: 13ms	remaining: 6.51s
# 300:	learn: 0.7066349	test: 0.7081039	best: 0.7081039 (161)	total: 2.45s	remaining: 1.62s
# 499:	learn: 0.7104219	test: 0.7081039	best: 0.7081039 (161)	total: 4.1s	remaining: 0us
#
# bestTest = 0.7081038552
# bestIteration = 161
#
# Shrink model to first 162 iterations.
# ----------------
# 0:	learn: 0.7005615	test: 0.6897409	best: 0.6897409 (0)	total: 10.7ms	remaining: 5.32s
# 300:	learn: 0.7076294	test: 0.6965129	best: 0.7078931 (1)	total: 3.19s	remaining: 2.11s
# 499:	learn: 0.7091195	test: 0.6919046	best: 0.7078931 (1)	total: 5.93s	remaining: 0us
#
# bestTest = 0.70789311
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# ----------------
# 0:	learn: 0.7012495	test: 0.7394065	best: 0.7394065 (0)	total: 10.5ms	remaining: 5.22s
# 300:	learn: 0.7088941	test: 0.7462487	best: 0.7508570 (112)	total: 2.52s	remaining: 1.66s
# 499:	learn: 0.7114710	test: 0.7462487	best: 0.7508570 (112)	total: 4.12s	remaining: 0us
#
# bestTest = 0.7508570305
# bestIteration = 112
#
# Shrink model to first 113 iterations.
# ----------------
# 0:	learn: 0.7028604	test: 0.7164353	best: 0.7164353 (0)	total: 10.8ms	remaining: 5.41s
# 300:	learn: 0.7083902	test: 0.7270007	best: 0.7376363 (1)	total: 2.49s	remaining: 1.64s
# 499:	learn: 0.7097988	test: 0.7316090	best: 0.7376363 (1)	total: 4.11s	remaining: 0us
#
# bestTest = 0.7376362819
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# ----------------
# 0:	learn: 0.6956964	test: 0.7356131	best: 0.7356131 (0)	total: 10.2ms	remaining: 5.1s
# 300:	learn: 0.7062816	test: 0.7356131	best: 0.7407553 (1)	total: 4.12s	remaining: 2.72s
# 499:	learn: 0.7086537	test: 0.7317495	best: 0.7407553 (1)	total: 5.88s	remaining: 0us
#
# bestTest = 0.7407553108
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# ----------------
# 0:	learn: 0.6841415	test: 0.7219990	best: 0.7219990 (0)	total: 10.8ms	remaining: 5.41s
# 300:	learn: 0.7082628	test: 0.7469231	best: 0.7492273 (141)	total: 2.54s	remaining: 1.68s
# 499:	learn: 0.7102754	test: 0.7492273	best: 0.7492273 (141)	total: 4.18s	remaining: 0us
#
# bestTest = 0.7492272676
# bestIteration = 141
#
# Shrink model to first 142 iterations.
# ----------------
# 0:	learn: 0.7022940	test: 0.7333090	best: 0.7333090 (0)	total: 10.4ms	remaining: 5.19s
# 300:	learn: 0.7136987	test: 0.7316792	best: 0.7339834 (186)	total: 2.6s	remaining: 1.72s
# 499:	learn: 0.7135357	test: 0.7286304	best: 0.7339834 (186)	total: 4.47s	remaining: 0us
#
# bestTest = 0.7339833652
# bestIteration = 186
#
# Shrink model to first 187 iterations.
# ----------------
# 0:	learn: 0.7038553	test: 0.6900219	best: 0.6900219 (0)	total: 26.4ms	remaining: 13.2s
# 300:	learn: 0.7103466	test: 0.6976790	best: 0.6999831 (191)	total: 3.98s	remaining: 2.63s
# 499:	learn: 0.7118743	test: 0.6991683	best: 0.7007278 (375)	total: 5.63s	remaining: 0us
#
# bestTest = 0.7007277734
# bestIteration = 375
#
# Shrink model to first 376 iterations.
# ----------------
# 0:	learn: 0.7047874	test: 0.6805735	best: 0.6805735 (0)	total: 10.3ms	remaining: 5.14s
# 300:	learn: 0.7117052	test: 0.6874543	best: 0.7036219 (1)	total: 2.53s	remaining: 1.68s
# 499:	learn: 0.7145636	test: 0.6882282	best: 0.7036219 (1)	total: 4.2s	remaining: 0us
#
# bestTest = 0.7036218833
# bestIteration = 1
#
# Shrink model to first 2 iterations.
# ----------------
# 0:	learn: 0.7011876	test: 0.7188467	best: 0.7188467 (0)	total: 10.6ms	remaining: 5.29s
# 300:	learn: 0.7060815	test: 0.7257556	best: 0.7257556 (226)	total: 2.59s	remaining: 1.71s
# 499:	learn: 0.7074105	test: 0.7257556	best: 0.7288231 (306)	total: 5.84s	remaining: 0us
#
# bestTest = 0.728823099
# bestIteration = 306
#
# Shrink model to first 307 iterations.
# ----------------
# 0:	learn: 0.6839590	test: 0.6939159	best: 0.6939159 (0)	total: 11.1ms	remaining: 5.52s
# 300:	learn: 0.7091976	test: 0.7076701	best: 0.7122784 (110)	total: 2.62s	remaining: 1.73s
# 499:	learn: 0.7102048	test: 0.7076701	best: 0.7122784 (110)	total: 4.28s	remaining: 0us
#
# bestTest = 0.7122784202
# bestIteration = 110
#
# Shrink model to first 111 iterations.
# ----------------
# 0:	learn: 0.7027971	test: 0.7107376	best: 0.7107376 (0)	total: 16.2ms	remaining: 8.09s
# 300:	learn: 0.7071370	test: 0.7237992	best: 0.7445082 (81)	total: 2.56s	remaining: 1.69s
# 499:	learn: 0.7106410	test: 0.7245625	best: 0.7445082 (81)	total: 4.16s	remaining: 0us
#
# bestTest = 0.7445082129
# bestIteration = 81
#
# Shrink model to first 82 iterations.
# ----------------
# 0:	learn: 0.7063972	test: 0.7337225	best: 0.7337225 (0)	total: 10.2ms	remaining: 5.08s
# 300:	learn: 0.7121371	test: 0.7529191	best: 0.7529191 (260)	total: 3.86s	remaining: 2.55s
# 499:	learn: 0.7141140	test: 0.7529191	best: 0.7529191 (260)	total: 5.89s	remaining: 0us
#
# bestTest = 0.752919058
# bestIteration = 260
#
# Shrink model to first 261 iterations.
# ----------------
# 0:	learn: 0.7013315	test: 0.7598032	best: 0.7598032 (0)	total: 10.8ms	remaining: 5.38s
# 300:	learn: 0.7044596	test: 0.7667298	best: 0.7697973 (111)	total: 2.59s	remaining: 1.71s
# 499:	learn: 0.7073179	test: 0.7697973	best: 0.7697973 (111)	total: 4.26s	remaining: 0us
#
# bestTest = 0.7697972916
# bestIteration = 111
#
# Shrink model to first 112 iterations.
# ----------------
# 0:	learn: 0.7041650	test: 0.7168443	best: 0.7168443 (0)	total: 10.1ms	remaining: 5.02s
# 300:	learn: 0.7094378	test: 0.7107376	best: 0.7168443 (0)	total: 2.43s	remaining: 1.61s
# 499:	learn: 0.7101584	test: 0.7130418	best: 0.7168443 (0)	total: 4.16s	remaining: 0us
#
# bestTest = 0.7168443075
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# ----------------
# 0:	learn: 0.6997887	test: 0.7291142	best: 0.7291142 (0)	total: 25ms	remaining: 12.5s
# 300:	learn: 0.7057025	test: 0.7237709	best: 0.7291142 (0)	total: 4.06s	remaining: 2.69s
# 499:	learn: 0.7090853	test: 0.7191626	best: 0.7291142 (0)	total: 5.7s	remaining: 0us
#
# bestTest = 0.7291142461
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# ----------------
# 0:	learn: 0.7066867	test: 0.7037686	best: 0.7037686 (0)	total: 10.1ms	remaining: 5.04s
# 300:	learn: 0.7120207	test: 0.6907636	best: 0.7037686 (0)	total: 2.57s	remaining: 1.7s
# 499:	learn: 0.7145573	test: 0.6907636	best: 0.7037686 (0)	total: 4.17s	remaining: 0us
#
# bestTest = 0.703768624
# bestIteration = 0
#
# Shrink model to first 1 iterations.
# ----------------

# %%
#average_f1_score = np.mean(best_f1_scores)
#average_best_thresh = np.mean(optimal_thresholds)
#print(f"Average F1 Score across folds: {average_f1_score}")
#print(f"Average Optimal Threshold across folds: {average_best_thresh}")

# Predict on test data using the average optimal threshold
y_pred_test_prob = clf.predict_proba(df_test[feat_cols])[:, 1]
y_pred_test = (y_pred_test_prob > 0.5).astype(int)

# %%
prediction = pd.DataFrame({
    'id': df_test['id'],
    'target': y_pred_test
})

prediction.to_csv("predictions",index = False)
prediction.head()
prediction['target'].value_counts()
# Out:
# target
# 0    1916
# 1    1347
# Name: count, dtype: int64
